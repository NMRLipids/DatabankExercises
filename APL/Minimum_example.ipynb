# %%
import sys

sys.path.insert(1, '../../Databank/Scripts/BuildDatabank/')
from databankLibrary import download_link, lipids_dict, databank

path = '../../Databank/Data/Simulations/'
db_data = databank(path)
systems = db_data.get_systems()

# %%
for system in systems:
    for key in system:
        print(key, ':',system[key])
    print('')
# Out:
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 22CHOL_200POPC_9000SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 55428
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [10, 12], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 0
# CPT : [['chol10_500ns.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 1025713704
# SOFTWARE_VERSION : 5.0
# FF : CHARMM36
# TOP : [['chol10.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3237420
# DATEOFRUNNING : 05/10/2021
# TPR : [['chol10.tpr']]
# TRJ : [['chol10_500ns.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/006/559/006559139e730fc43b244726992145c2f37a1461/3c99810c45a83b4ba0e54a69fdea8817498a8930/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : pre-2020
# SYSTEM : 200POPC_9000SOL_81SOD_81CLA_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 53962
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : http://mmkluster.fos.su.se/slipids/ and https://bitbucket.org/hseara/ions/
# COMPOSITION : {'CLA': {'NAME': 'CL', 'COUNT': 81, 'MAPPING': 'mappingCL.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCslipids.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PwaterSlipids.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 81, 'MAPPING': 'mappingNA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100100.0
# TRAJECTORY_SIZE : 199059704
# SOFTWARE_VERSION : 4.6
# FF : Slipids for lipids, Kohagen for NaCl
# TOP : [['500.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.35193
# DATEOFRUNNING : 12/10/2021
# TPR : [['500.tpr']]
# TRJ : [['500.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/007/494/007494777cfaf4a3bbaf66335df4b9aa48c990e0/542f342c6c9c1b0647bcb98de53be96d5af4b505/
#
# AUTHORS_CONTACT : Ollila
# FF_DATE : None
# SYSTEM : 200POPC_9000SOL_313K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 313.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 53800
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : None
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 20
# CPT : [['run.cpt']]
# TRJLENGTH : 200010.0
# TRAJECTORY_SIZE : 3979765856
# SOFTWARE_VERSION : 5
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.4040423
# DATEOFRUNNING : 01/10/2021
# TPR : [['run.tpr']]
# TRJ : [['run.xtc']]
# LOG : [['run.log']]
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/007/ed1/007ed172073ee268b07f29ecd413eb9de13a3d47/895cd634e9106b949e0c15cd8873592748b66fed/
#
# AUTHORS_CONTACT : Thomas Piggot
# FF_DATE : pre-2020
# SYSTEM : 128POPS_4880SOL_128SOD_298K_v2
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 29824
# EXPERIMENT : {'POPS': {'10.1021/acs.jctc.9b00824': '10.1021/acs.jctc.9b00824/1', '10.1021/acs.jpcb.9b06091': '10.1021/acs.jpcb.9b06091/1'}}
# FF_SOURCE : starting structure from CHARMM-GUI
# COMPOSITION : {'POPS': {'NAME': 'POPS', 'COUNT': [64, 64], 'MAPPING': 'mappingPOPSslipids.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 4480, 'MAPPING': 'mappingSPCwater.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 128, 'MAPPING': 'mappingNA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100050.0
# TRAJECTORY_SIZE : 221910896
# SOFTWARE_VERSION : None
# FF : Slipids
# TOP : None
# PREEQTIME : 400
# DOI : 10.5281/zenodo.1129441
# DATEOFRUNNING : 12/10/2021
# TPR : [['for-md-Slipids_10A_cut-off_LJ-PME_POPS_298K_v2.tpr']]
# TRJ : [['md-Slipids_LJ-PME_POPS_v2_400-500ns_skip10.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/02b/984/02b98418d9965749ac943ecae9627cfdd1dfbdcd/7339faa76da6c93cfee03e59f399e2eed1628b53/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 200POPC_9000SOL_73CAL_146CLA_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 54019
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : http://www.charmm-gui.org for lipids and https://bitbucket.org/hseara/ions/ for ions
# COMPOSITION : {'SOL': {'NAME': 'TIP3', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'CAL': {'NAME': 'CA', 'COUNT': 73, 'MAPPING': 'mappingCA.txt'}, 'CLA': {'NAME': 'CL', 'COUNT': 146, 'MAPPING': 'mappingCL.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100100.0
# TRAJECTORY_SIZE : 200283872
# SOFTWARE_VERSION : 5.0
# FF : CHARMM36 with ECC-scaled ions
# TOP : [['topol.top']]
# PREEQTIME : 700
# DOI : 10.5281/zenodo.45008
# DATEOFRUNNING : 12/10/2021
# TPR : [['md.tpr']]
# TRJ : [['md.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/02e/922/02e9220d27c2d6f4aa76992ae66014ac8d5557e0/4237bd2c8e11c1b48325386fd672fd6fd3e75894/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 232DAPC_56CHOL_11520SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 70720
# EXPERIMENT : {'CHOL': {}, 'DAPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [28, 28], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 11520, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'DAPC': {'NAME': 'DAPC', 'COUNT': [116, 116], 'MAPPING': 'mappingDAPCcharmm.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DAPC_AA_CHOL20_310.cpt']]
# TRJLENGTH : 1000100.0
# TRAJECTORY_SIZE : 2638277776
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['DAPC_AA_CHOL20.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.2653721
# DATEOFRUNNING : 07/10/2021
# TPR : [['DAPC_AA_CHOL20_310.tpr']]
# TRJ : [['DAPC_AA_CHOL20_310.xtc']]
# LOG : [['DAPC_AA_CHOL20_310.log']]
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/030/bec/030bec1358db2fe351b5f52ba856394ac2b2c35e/e665ce365a39b6e27354a8274706cf6fc1de4716/
#
# AUTHORS_CONTACT : Jesper J. Madsen
# FF_DATE : None
# SYSTEM : 400POPC_100POPG_419CAL_738CLA_298K_123398Atoms
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 123398
# EXPERIMENT : {'POPG': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [50, 50], 'MAPPING': 'mappingPOPGcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 18647, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [200, 200], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'CAL': {'NAME': 'CAL', 'COUNT': 419, 'MAPPING': 'mappingCAL.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 738, 'MAPPING': 'mappingCLA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 200100.0
# TRAJECTORY_SIZE : 929462176
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3483785
# DATEOFRUNNING : 01/10/2021
# TPR : [['step7_1.tpr']]
# TRJ : [['run.wrapped.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/03a/98a/03a98aeace25f568384fe703e1f0d3b4ac01af25/5004da904d772ea193d59c0a0c6a3b830b713816/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 260DOPC_28CHOL_11520SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 72512
# EXPERIMENT : {'CHOL': {}, 'DOPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [14, 14], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 11520, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'DOPC': {'NAME': 'DOPC', 'COUNT': [130, 130], 'MAPPING': 'mappingDOPCcharmm.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DOPC_AA_CHOL10_310.cpt']]
# TRJLENGTH : 1000100.0
# TRAJECTORY_SIZE : 2705193720
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['DOPC_AA_CHOL10.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.2653721
# DATEOFRUNNING : 07/10/2021
# TPR : [['DOPC_AA_CHOL10_310.tpr']]
# TRJ : [['DOPC_AA_CHOL10_310.xtc']]
# LOG : [['DOPC_AA_CHOL10_310.log']]
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/0a3/34e/0a334eb7da0eb8b9132ee5052392f58587e114a3/e9dc01b944365772afa0038d1349e15b03fe4b6c/
#
# AUTHORS_CONTACT : Walter, Vivien; Ruscher, Celine; Benzerara, Olivier; Marques, Carlos; Thalmann, Fabrice
# FF_DATE : June 2015
# SYSTEM : 212DPPC_29826SOL_298K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : 10.1039/D0CP02058C
# NUMBER_OF_ATOMS : 117038
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [106, 106], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 29826, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 50005.0
# TRAJECTORY_SIZE : 4366026280
# SOFTWARE_VERSION : 2016.4
# FF : CHARMM36
# TOP : None
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3950029
# DATEOFRUNNING : 05/10/2021
# TPR : [['dppc_298k.tpr']]
# TRJ : [['dppc_298k.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/0a4/101/0a41017641414540973e921ed22528d1f3dc414b/3c0936e61fa40cce74fd1828a2697742709e91fb/
#
# AUTHORS_CONTACT : Walter, Vivien; Ruscher, Celine; Benzerara, Olivier; Marques, Carlos; Thalmann, Fabrice
# FF_DATE : June 2015
# SYSTEM : 212DPPC_29826SOL_288K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 288.0
# PUBLICATION : 10.1039/D0CP02058C
# NUMBER_OF_ATOMS : 117038
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [106, 106], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 29826, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 50005.0
# TRAJECTORY_SIZE : 4365700484
# SOFTWARE_VERSION : 2016.4
# FF : CHARMM36
# TOP : None
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3950029
# DATEOFRUNNING : 05/10/2021
# TPR : [['dppc_288k.tpr']]
# TRJ : [['dppc_288k.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/0bc/296/0bc296850dd41d32a6e9aa4ac2b5dd4e84a6605f/e64b1a6ceccc9a361529be902c17c2b4b0394484/
#
# FF_DATE : ?/?/2020
# TYPEOFSYSTEM : lipid bilayer
# SYSTEM : POPC:POPG(1:1)_T298K
# TEMPERATURE : 298.0
# NUMBER_OF_ATOMS : 133800
# EXPERIMENT : {'POPG': {}, 'POPC': {'10.1002/j.1460-2075.1987.tb02595.x': '10.1002/j.1460-2075.1987.tb02595.x/5'}}
# FF_SOURCE : CHARMM-GUI
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [75, 75], 'MAPPING': 'mappingPOPGcharmm.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [75, 75], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 31500, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'SOD': {'NAME': 'SOD', 'COUNT': 150, 'MAPPING': 'mappingSOD.txt'}}
# TIMELEFTOUT : 0
# TRJLENGTH : 300020.0
# DATEOFRUNNING : 01/10/2021
# FF : CHARMM36
# SOFTWARE : gromacs
# PREEQTIME : 100
# DOI : 10.5281/zenodo.3997116
# TRAJECTORY_SIZE : 7413293748
# TPR : [['run_400ns.tpr']]
# TRJ : [['100-400ns.xtc']]
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/0c2/1a9/0c21a9be136ea0eb9df9e5c6cdc19f723a0af245/9ac73b6a98acb54a7a67a5d690794ad7f1e4a1d1/
#
# FF_DATE : ??
# TYPEOFSYSTEM : lipid bilayer
# SYSTEM : POPG_T298K
# TEMPERATURE : 298.0
# NUMBER_OF_ATOMS : 27434
# EXPERIMENT : {'POPG': {'10.5281/zenodo.4748647': '10.1021/jacs.1c05549/1'}}
# FF_SOURCE : CHARMM-GUI
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [59, 59], 'MAPPING': 'mappingPOPGcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 4110, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'SOD': {'NAME': 'POT', 'COUNT': 118, 'MAPPING': 'mappingPOT.txt'}}
# TIMELEFTOUT : 20
# TRJLENGTH : 100010.0
# DATEOFRUNNING : 01/10/2021
# FF : CHARMM36
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1011096
# TRAJECTORY_SIZE : 1012328064
# TPR : [['run2.tpr']]
# TRJ : [['run2.xtc']]
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/0d5/d1d/0d5d1dcb43e775faf4e53c4f9ff255a67481bd38/9b487701b24d3fad83991e311188b08d3d5ea768/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 86CHOL_200POPC_9000SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 60164
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [43, 43], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 0
# CPT : [['chol30_500ns.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 1123757108
# SOFTWARE_VERSION : 5.0
# FF : CHARMM36
# TOP : [['chol30.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3237420
# DATEOFRUNNING : 05/10/2021
# TPR : [['chol30.tpr']]
# TRJ : [['chol30_500ns.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/0ee/05e/0ee05e1e79df817550a61e81325640721a390b8c/9bff2a04f58c3e886cee2ee1ab30c056d1fc9393/
#
# AUTHORS_CONTACT : Hanne Antila ()
# FF_DATE : ?/?/????
# SYSTEM : Berger_POPC_T303K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 303.0
# UNITEDATOM_DICT : None
# PUBLICATION : ??
# NUMBER_OF_ATOMS : 65330
# FFSOL : SPC
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : https://zenodo.org/record/1402417/
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [128, 128], 'MAPPING': 'mappingPOPCberger.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 10342, 'MAPPING': 'mappingSPCwater.txt'}}
# TIMELEFTOUT : 100
# TRJLENGTH : 1200010.0
# TRAJECTORY_SIZE : 29078150944
# SOFTWARE_VERSION : Gpu_version_2020.1
# FF : Berger
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.4537207
# DATEOFRUNNING : 01/10/2021
# TPR : [['protonated.tpr']]
# TRJ : [['prottraj.xtc']]
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/102/dfa/102dfa390326acd775347b1d703ccfa85e033cd8/1ad80d5d253e861f01d8f16e0d1590c6ef962916/
#
# AUTHORS_CONTACT : Ollila, O. H. S.
# FF_DATE : None
# SYSTEM : 110POPC_22POPS_4929SOL_62POT_40CLA_298K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 32423
# EXPERIMENT : {'POPS': {}, 'POPC': {}}
# FF_SOURCE : CHARM-GUI v1.7
# COMPOSITION : {'POPS': {'NAME': 'POPS', 'COUNT': [11, 11], 'MAPPING': 'mappingPOPScharmm.txt'}, 'POT': {'NAME': 'POT', 'COUNT': 62, 'MAPPING': 'mappingPOT.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [55, 55], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 4929, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 40, 'MAPPING': 'mappingCLA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 150010.0
# TRAJECTORY_SIZE : 1808432868
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 50
# DOI : 10.5281/zenodo.1493241
# DATEOFRUNNING : 01/10/2021
# TPR : [['topol.tpr']]
# TRJ : [['traj.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/107/7fb/1077fb2bdc91269d2c3e5c22f5560d62ca0901d1/23fdf201323693d01eedcd67d30a1caf11239e33/
#
# AUTHORS_CONTACT : Martinez-Seara, Hector
# FF_DATE : None
# SYSTEM : 72DPPC_2880SOL_325K_rmcomm_leaflets
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 325.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 18000
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : CHARMM-GUI v1.6
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [36, 36], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 2880, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DPPC_72_325K_rmcomm_leaflets_md.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 332189196
# SOFTWARE_VERSION : 5.0.4
# FF : CHARMM36 (center of mass removed independently for upper leaflet, lower leaflet and water+ions)
# TOP : [['DPPC_72_325K_rmcomm_leaflets_md.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1009607
# DATEOFRUNNING : 12/10/2021
# TPR : [['DPPC_72_325K_rmcomm_leaflets_md.tpr']]
# TRJ : [['DPPC_72_325K_rmcomm_leaflets_md.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/116/9a0/1169a0f959c9caac1671425c8ae4cd6e255dc49f/e0dbaa355f6b5faeeef73dd79514eb8364492a88/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 50CHOL_200POPC_9000SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 57500
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [25, 25], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 0
# CPT : [['chol20_500ns.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 1068174512
# SOFTWARE_VERSION : 5.0
# FF : CHARMM36
# TOP : [['chol20.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3237420
# DATEOFRUNNING : 05/10/2021
# TPR : [['chol20.tpr']]
# TRJ : [['chol20_500ns.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/118/63c/11863cc69a9981c131cf84c5c0a9b0e121d4fd82/7460bf1dfb99b7838374837e35ccca3c416a7659/
#
# FF_DATE : ??
# POPG : POPG
# SYSTEM : POPC50%chol_T303K
# TYPEOFSYSTEM : lipid bilayer
# POPS : POPS
# FFSOL : TIP3P
# NUMBER_OF_ATOMS : 30128
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# FF_SOURCE : ??
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [40, 40], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [40, 40], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 4496, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TRJ : [['POPC_50CHL.xtc']]
# TIMELEFTOUT : 100
# POPE : POPE
# CLA : CL
# DATEOFRUNNING : 01/10/2021
# FF : CHARMM36
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.14068
# TRAJECTORY_SIZE : 1111756544
# TPR : [['POPC_50CHL.tpr']]
# POT : K
# TEMPERATURE : 303.0
# CAL : CA
# SOD : NA
# TRJLENGTH : 200020.0
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/16a/a70/16aa70c118dbfdbb7bd8e0462575e2776e0dec9a/ba8633f6385dbf4c344b8a7580603620b0d52603/
#
# AUTHORS_CONTACT : Jesper J. Madsen
# FF_DATE : None
# SYSTEM : 250POPC_250POPG_445CAL_640CLA_298K_1206774Atoms
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 120677
# EXPERIMENT : {'POPG': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [125, 125], 'MAPPING': 'mappingPOPGcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 18114, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [125, 125], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'CAL': {'NAME': 'CAL', 'COUNT': 445, 'MAPPING': 'mappingCAL.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 640, 'MAPPING': 'mappingCLA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 200100.0
# TRAJECTORY_SIZE : 908659676
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3483793
# DATEOFRUNNING : 01/10/2021
# TPR : [['step7_1.tpr']]
# TRJ : [['run.wrapped.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/16e/05e/16e05ef76ec9e852afadd7e2bc1639becf9c153b/abdfd2e517f2b5aefdefea5ad0831e3f7d0f4ab8/
#
# AUTHORS_CONTACT : Martinez-Seara, Hector; Javanainen, Matti; Rissanen, Sami; Lolicato, Fabio
# FF_DATE : None
# SYSTEM : 512DPPC_20480SOL_325K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 325.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 128000
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : CHARMM-GUI v1.6
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [256, 256], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 20480, 'MAPPING': 'mappingSPCwater.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DPPC_512_325K_md.cpt']]
# TRJLENGTH : 400000.0
# TRAJECTORY_SIZE : 1914769252
# SOFTWARE_VERSION : 5.0.4
# FF : CHARMM36
# TOP : [['DPPC_512_325K_md.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.16254
# DATEOFRUNNING : 05/10/2021
# TPR : [['DPPC_512_325K_md.tpr']]
# TRJ : [['DPPC_512_325K_md_part0.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/174/c74/174c746e212577c63e6df6c6910b2e9a1d587241/6fb923ea75663dbeea13c0fa79015ae11dea9157/
#
# AUTHORS_CONTACT : Jesper J. Madsen
# FF_DATE : None
# SYSTEM : 150POPC_150POPS_150POT_298K_71655Atoms
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 71655
# EXPERIMENT : {'POPS': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPS': {'NAME': 'POPS', 'COUNT': [75, 75], 'MAPPING': 'mappingPOPScharmm.txt'}, 'POT': {'NAME': 'POT', 'COUNT': 150, 'MAPPING': 'mappingPOT.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [75, 75], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 10785, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 20
# CPT : None
# TRJLENGTH : 200100.0
# TRAJECTORY_SIZE : 534969816
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.2542164
# DATEOFRUNNING : 01/10/2021
# TPR : [['step7_1.tpr']]
# TRJ : [['run.wrapped.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/18e/794/18e7944e27be44e0efbb90590c5f88ca29664652/350258dcc317cd9f2bf313b978af19781b5f74cd/
#
# AUTHORS_CONTACT : Vivien Walter; Celine Ruscher; Olivier Benzerara; Fabrice Thalmann
# FF_DATE : June 2015
# SYSTEM : 256DPPC_42642SOL_358K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 358.0
# PUBLICATION : 10.1002/jcc.26508
# NUMBER_OF_ATOMS : 161206
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [128, 128], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 42642, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 25005.0
# TRAJECTORY_SIZE : 2995251216
# SOFTWARE_VERSION : 2020
# FF : CHARMM36
# TOP : None
# PREEQTIME : 0
# DOI : 10.5281/zenodo.4300706
# DATEOFRUNNING : 05/10/2021
# TPR : [['dppc_fluid.tpr']]
# TRJ : [['dppc_fluid.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/190/463/1904639f46788801d29a5f44f015048174bcf6b4/97cde4b14332cf79b9cd757e8d08a132f0e73223/
#
# AUTHORS_CONTACT : Martinez-Seara, Hector
# FF_DATE : None
# SYSTEM : 128DPPC_4800SOL_32CHOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 33408
# EXPERIMENT : {'CHOL': {}, 'DPPC': {}}
# FF_SOURCE : CHARMM-GUI v1.6
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [16, 16], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'DPPC': {'NAME': 'DPPC', 'COUNT': [64, 64], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 4800, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DPPC_128_CHL1_32_310K_md.cpt']]
# TRJLENGTH : 1000100.0
# TRAJECTORY_SIZE : 1240484768
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['DPPC_128_CHL1_32_310K_md.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1010131
# DATEOFRUNNING : 01/10/2021
# TPR : [['DPPC_128_CHL1_32_310K_md.tpr']]
# TRJ : [['DPPC_128_CHL1_32_310K_md.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/19e/f1b/19ef1b2957f3fd59f5633581a55f8afd61788f08/4203213cd437b309b98debf97e0df15a71c19ce2/
#
# AUTHORS_CONTACT : Nencini, Ricky
# FF_DATE : None
# SYSTEM : 200POPC_9000SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 53800
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 367100.0
# TRAJECTORY_SIZE : 730371420
# SOFTWARE_VERSION : 5.1.4
# FF : ECC-CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.2562080
# DATEOFRUNNING : 01/10/2021
# TPR : [['topol.tpr']]
# TRJ : [['traj_comp.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/7a7/591/7a7591afc8a748eb8a19807401ef6d297f36c202/de3454b64be6b9c9d2dc17d873ca1cfbca1c6766/
#
# AUTHORS_CONTACT : ANTONIO PEON
# FF_DATE : None
# SYSTEM : 500POPG_25000SOL_500SOD_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 139000
# EXPERIMENT : {'POPG': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [250, 250], 'MAPPING': 'mappingPOPGcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 25000, 'MAPPING': 'mappingTIP3Pwater.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 500, 'MAPPING': 'mappingNA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100010.0
# TRAJECTORY_SIZE : 5149404852
# SOFTWARE_VERSION : 2018.3
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 400
# DOI : 10.5281/zenodo.3237463
# DATEOFRUNNING : 01/10/2021
# TPR : [['md_0.tpr']]
# TRJ : [['total_4_500.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/7b5/dac/7b5dacbf8d86861371b86fcfb541daaaa1b08756/f055c6e1ecf88e3e920f5dc29f0527f31e114c82/
#
# AUTHORS_CONTACT : Martinez-Seara, Hector
# FF_DATE : None
# SYSTEM : 72POPC_2239SOL_303K_rmcomm_leaflets
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 303.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 16365
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.6
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [36, 36], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 2239, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : [['POPC_72_303K_rmcomm_leaflets_low_hydration_md.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 303543904
# SOFTWARE_VERSION : 5.0.4
# FF : CHARMM36 (center of mass removed independently for upper leaflet, lower leaflet and water+ions)
# TOP : [['POPC_72_303K_rmcomm_leaflets_low_hydration_md.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1009607
# DATEOFRUNNING : 12/10/2021
# TPR : [['POPC_72_303K_rmcomm_leaflets_low_hydration_md.tpr']]
# TRJ : [['POPC_72_303K_rmcomm_leaflets_low_hydration_md.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/7cf/9df/7cf9df0cc6fe319d93e3f5635b2c6b517513cbf5/b1e8bdfc572caaf640f503bff2726ed0a1a793a3/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : pre-2020
# SYSTEM : 200POPC_9000SOL_122SOD_122CLA_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 54044
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : http://mmkluster.fos.su.se/slipids/ and https://bitbucket.org/hseara/ions/
# COMPOSITION : {'CLA': {'NAME': 'CL', 'COUNT': 122, 'MAPPING': 'mappingCL.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCslipids.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PwaterSlipids.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 122, 'MAPPING': 'mappingNA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100100.0
# TRAJECTORY_SIZE : 200061900
# SOFTWARE_VERSION : 4.6
# FF : Slipids for lipids, Kohagen for NaCl
# TOP : [['750.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.35193
# DATEOFRUNNING : 12/10/2021
# TPR : [['750.tpr']]
# TRJ : [['750.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/7ec/129/7ec129e267d37f2980f994cec3d4fb0aad9b561d/7d1a9c4c77caecc96b68d512514fdf23f83159f9/
#
# AUTHORS_CONTACT : Ollila, Samuli
# FF_DATE : None
# SYSTEM : 72POPC_2190SOL_26CLA_26NA_303K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 303.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 16270
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'CLA': {'NAME': 'CL', 'COUNT': 26, 'MAPPING': 'mappingCLA.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [36, 36], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 2190, 'MAPPING': 'mappingSPCwater.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 26, 'MAPPING': 'mappingSOD.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 40005.0
# TRAJECTORY_SIZE : 479819256
# SOFTWARE_VERSION : 4.5
# FF : CHARMM36
# TOP : [['popc.top']]
# PREEQTIME : 13
# DOI : 10.5281/zenodo.32497
# DATEOFRUNNING : 01/10/2021
# TPR : [['popcRUN2.tpr']]
# TRJ : [['popcRUN13-73ns.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/7f6/fbc/7f6fbc9ec469b1d33d2ec93cccdd86768443988f/f7a6d748844cb56fec39dd0c2f27b9483a291114/
#
# AUTHORS_CONTACT : Ollila, Samuli
# FF_DATE : None
# SYSTEM : 72POPC_2168SOL_37CLA_37NA_303K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 303.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 16226
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : charmm2gmx.py
# COMPOSITION : {'CLA': {'NAME': 'CL', 'COUNT': 37, 'MAPPING': 'mappingCLA.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [36, 36], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 2168, 'MAPPING': 'mappingSPCwater.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 37, 'MAPPING': 'mappingSOD.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 60010.0
# TRAJECTORY_SIZE : 359802172
# SOFTWARE_VERSION : 4.5
# FF : CHARMM36
# TOP : [['popc.top']]
# PREEQTIME : 20
# DOI : 10.5281/zenodo.32498
# DATEOFRUNNING : 01/10/2021
# TPR : [['popcRUN2.tpr']]
# TRJ : [['popcRUN2-4.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/808/c7a/808c7aeb6d972c46e68b73262779414b4dad7295/5f945ed9d7f9e2cd38133fec4afb757eb7db3542/
#
# DOI : 10.5281/zenodo.3243329
# SOFTWARE : gromacs
# TRJ : [['chol40_500ns.xtc']]
# TPR : [['chol40.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Javanainen, Matti
# SYSTEM : 200POPC_9000SOL_134CHOL_310K
# SOFTWARE_VERSION : 4.6
# FF : Slipids
# FF_SOURCE : http://mmkluster.fos.su.se/slipids/
# FF_DATE : pre-2020
# CPT : [['chol40_500ns.cpt']]
# LOG : None
# TOP : [['chol40.top']]
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'MAPPING': 'mappingPOPCslipids.txt', 'COUNT': [100, 100]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingTIP3PwaterSlipids.txt', 'COUNT': 15030}, 'CHOL': {'NAME': 'CHL1', 'MAPPING': 'mappingCHOLESTEROLslipid.txt', 'COUNT': [67, 67]}}
# TRAJECTORY_SIZE : 1510515552
# TRJLENGTH : 500100.0
# TEMPERATURE : 310.0
# NUMBER_OF_ATOMS : 81806
# DATEOFRUNNING : 22/10/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'POPC': {}, 'CHOL': {}}
# path : ../../Databank/Data/Simulations/815/ad3/815ad324c34bfdfcbdc34ead95481bf38723c42b/657393f95833364bff072b6824252dbd998c31c9/
#
# AUTHORS_CONTACT : Nencini, Ricky
# FF_DATE : None
# SYSTEM : 200POPC_9000SOL_74CAL_146CLA_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 54019
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'SOL': {'NAME': 'SOL', 'COUNT': 9000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'CAL': {'NAME': 'CAL', 'COUNT': 73, 'MAPPING': 'mappingCAL.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 146, 'MAPPING': 'mappingCLA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 361400.0
# TRAJECTORY_SIZE : 723082340
# SOFTWARE_VERSION : 5.1.4
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1198171
# DATEOFRUNNING : 01/10/2021
# TPR : [['topol.tpr']]
# TRJ : [['traj_comp.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/818/441/818441b1a180862d99b4c2980f988a0e67e6fbb4/edd860b5790aafabeffc15055efdbdada696a1a3/
#
# AUTHORS_CONTACT : Thomas Piggot
# FF_DATE : None
# SYSTEM : 110POPC_22POPS_22POT_4620SOL_298K_v1
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 31416
# EXPERIMENT : {'POPS': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI
# COMPOSITION : {'POPS': {'NAME': 'POPS', 'COUNT': [11, 11], 'MAPPING': 'mappingPOPScharmm.txt'}, 'POT': {'NAME': 'POT', 'COUNT': 22, 'MAPPING': 'mappingPOT.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [55, 55], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 4620, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100050.0
# TRAJECTORY_SIZE : 233708580
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : None
# PREEQTIME : 400
# DOI : 10.5281/zenodo.1182658
# DATEOFRUNNING : 04/10/2021
# TPR : [['for-md-CHARMM36_POPS_POPC_K_298K_10A-switch_v1.tpr']]
# TRJ : [['md-CHARMM36_POPS_POPC_K_298K_10A-switch_v1_400-500ns_skip10.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/833/b9c/833b9caa5aa455eacae414e4504f479a9b6949bb/bfb99c2b9c154a92eddcb25c4a888797823daaf6/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 22CHOL_200POPC_9000SOL_73CAL_146CLA_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.15
# PUBLICATION : None
# NUMBER_OF_ATOMS : 55647
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# FF_SOURCE : http://mackerell.umaryland.edu/charmm_ff.shtml
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [13, 9], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 9000, 'MAPPING': 'mappingTIP3Pwater.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [100, 100], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'CAL': {'NAME': 'Cal', 'COUNT': 73, 'MAPPING': 'mappingCAL.txt'}, 'CLA': {'NAME': 'CL', 'COUNT': 146, 'MAPPING': 'mappingCL.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 2000100.0
# TRAJECTORY_SIZE : 4124327284
# SOFTWARE_VERSION : 5.0
# FF : CHARMM36
# TOP : [['md10.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.259365
# DATEOFRUNNING : 05/10/2021
# TPR : [['md10.tpr']]
# TRJ : [['md10.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/84e/730/84e730ce5fc952714f30b3fad9f9a12d72579fcb/8bc3a15b282f4b28f49e40cb5a55e15d5e8b1a00/
#
# DOI : 10.5281/zenodo.3539129
# SOFTWARE : gromacs
# TRJ : [['dppc_310.xtc']]
# TPR : [['dppc_310.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Javanainen, Matti; Martinez-Seara, Hector; Vattulainen, Ilpo
# SYSTEM : 1152DPPC_46440SOL_124SOD_124CLA_310K
# SOFTWARE_VERSION : None
# FF : Slipids
# FF_SOURCE : None
# FF_DATE : pre-2020
# CPT : [['dppc_310.cpt']]
# LOG : [['dppc_310.log']]
# TOP : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'MAPPING': 'mappingDPPCslipid.txt', 'COUNT': [576, 576]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingTIP3PwaterSlipids.txt', 'COUNT': 46440}, 'SOD': {'NAME': 'NA', 'MAPPING': 'mappingNA.txt', 'COUNT': 124}, 'CLA': {'NAME': 'CL', 'MAPPING': 'mappingCL.txt', 'COUNT': 124}}
# TRAJECTORY_SIZE : 3242665028
# TRJLENGTH : 300100.0
# TEMPERATURE : 310.0
# NUMBER_OF_ATOMS : 289328
# DATEOFRUNNING : 01/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'DPPC': {}}
# path : ../../Databank/Data/Simulations/86a/f7e/86af7e0446c1bcdbd30766871258b65093351a12/ac10be8aa0a31d1bf48ac7a4400a75adb71008eb/
#
# FF_DATE : ??
# POPG : POPG
# SYSTEM : POPC_T310K
# TYPEOFSYSTEM : lipid bilayer
# POPS : POPS
# FFSOL : TIP3P
# NUMBER_OF_ATOMS : 142000
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : ??
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [250, 250], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 25000, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TRJ : [['total_4_500.xtc']]
# TIMELEFTOUT : 0
# POPE : POPE
# CLA : CL
# DATEOFRUNNING : 01/10/2021
# FF : CHARMM36
# SOFTWARE : gromacs
# PREEQTIME : 400
# DOI : 10.5281/zenodo.3247813
# TRAJECTORY_SIZE : 5259838592
# TPR : [['md_0.tpr']]
# POT : K
# TEMPERATURE : 310.0
# CAL : CA
# SOD : NA
# TRJLENGTH : 100010.0
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/874/256/87425634a08154ef405aea238908c2891031d54c/17afdd19e48164c2b201d4cc9bfef1ccf06cd281/
#
# DOI : 10.5281/zenodo.259341
# SOFTWARE : gromacs
# TRJ : [['md30.xtc']]
# TPR : [['md30.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Javanainen, Matti
# SYSTEM : 86CHOL_200POPC_9000SOL_162SOD_162CLA_310K
# SOFTWARE_VERSION : 4.6
# FF : Slipids with ions by Smith & Dang
# FF_SOURCE : http://www.fos.su.se/~sasha/SLipids/; ion parameters from https://bitbucket.org/hseara/ions/
# FF_DATE : pre-2020
# CPT : None
# LOG : None
# TOP : [['md30.top']]
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'MAPPING': 'mappingCHOLESTEROLslipid.txt', 'COUNT': [41, 45]}, 'POPC': {'NAME': 'POPC', 'MAPPING': 'mappingPOPCslipids.txt', 'COUNT': [100, 100]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingTIP3PwaterSlipids.txt', 'COUNT': 9000}, 'SOD': {'NAME': 'NAs', 'MAPPING': 'mappingNAs.txt', 'COUNT': 162}, 'CLA': {'NAME': 'CL', 'MAPPING': 'mappingCL.txt', 'COUNT': 162}}
# TRAJECTORY_SIZE : 449769704
# TRJLENGTH : 200100.0
# TEMPERATURE : 310.0
# NUMBER_OF_ATOMS : 60488
# DATEOFRUNNING : 01/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# path : ../../Databank/Data/Simulations/87f/d72/87fd72d7d0b20475b8ed3656dcdde54edba77f5e/0cf7b5e72d653004a8996d04c5d6066b26310a5e/
#
# AUTHORS_CONTACT : Vivien Walter; Celine Ruscher; Olivier Benzerara; Fabrice Thalmann
# FF_DATE : June 2015
# SYSTEM : 192DPPC_318692SOL_288K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 288.0
# PUBLICATION : 10.1002/jcc.26508
# NUMBER_OF_ATOMS : 160756
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [128, 128], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 42492, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 25005.0
# TRAJECTORY_SIZE : 2979241284
# SOFTWARE_VERSION : 2020
# FF : CHARMM36
# TOP : None
# PREEQTIME : 0
# DOI : 10.5281/zenodo.4300706
# DATEOFRUNNING : 05/10/2021
# TPR : [['dppc_gel.tpr']]
# TRJ : [['dppc_gel.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/888/c03/888c031cd88bd97a5584a120dee76bf673e438ff/369daa4fed207d6e3d3199466c3f260535334f11/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 28CHOL_130DOPC_115DDOPC_10920SOL_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 69102
# EXPERIMENT : {'CHOL': {}, 'DDOPC': {}, 'DOPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [14, 14], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 10920, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'DDOPC': {'NAME': 'DDPC', 'COUNT': [0, 115], 'MAPPING': 'mappingDDOPCcharmm.txt'}, 'DOPC': {'NAME': 'DOPC', 'COUNT': [130, 0], 'MAPPING': 'mappingDOPCcharmm.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DOPC_DDPC_AA_CHOL10_310.cpt']]
# TRJLENGTH : 1000100.0
# TRAJECTORY_SIZE : 2579033088
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['DOPC_DDPC_AA_CHOL10.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.2653723
# DATEOFRUNNING : 07/10/2021
# TPR : [['DOPC_DDPC_AA_CHOL10_310.tpr']]
# TRJ : [['DOPC_DDPC_AA_CHOL10_310.xtc']]
# LOG : [['DOPC_DDPC_AA_CHOL10_310.log']]
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/895/c8e/895c8ebafa41c32a750d104df7523d4f71088470/c3f3385efdfacf66ce7023fe653f18259af20c10/
#
# AUTHORS_CONTACT : Martinez-Seara, Hector
# FF_DATE : None
# SYSTEM : 512POPC_20480SOLtip3_55SOD_55CLA_310K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 130158
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.6
# COMPOSITION : {'CLA': {'NAME': 'CL', 'COUNT': 55, 'MAPPING': 'mappingCL.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [256, 256], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 20480, 'MAPPING': 'mappingTIP3Pwater.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 55, 'MAPPING': 'mappingNA.txt'}}
# TIMELEFTOUT : 0
# CPT : [['POPC_512_NaCl_150mM_310K_tip3p_md.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 2441203728
# SOFTWARE_VERSION : 5.0.4
# FF : CHARMM36
# TOP : [['POPC_512_NaCl_150mM_310K_tip3p_md.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1010083
# DATEOFRUNNING : 01/10/2021
# TPR : [['POPC_512_NaCl_150mM_310K_tip3p_md.tpr']]
# TRJ : [['POPC_512_NaCl_150mM_310K_tip3p_md.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/89a/9a4/89a9a48c2494b41ea60988ceb5cf197564bb9b73/9d27707ef545963e0723252396311bfa590a7f5f/
#
# DOI : 10.5281/zenodo.259349
# SOFTWARE : gromacs
# TRJ : [['md30.xtc']]
# TPR : [['md30.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Javanainen, Matti
# SYSTEM : 86CHOL_200POPC_9000SOL_73CAL_146CLA_310K
# SOFTWARE_VERSION : 4.6
# FF : Slipids with default Amber ions parameters (type C0)
# FF_SOURCE : http://www.fos.su.se/~sasha/SLipids/
# FF_DATE : pre-2020
# CPT : [['md30.cpt']]
# LOG : None
# TOP : [['md30.top']]
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'MAPPING': 'mappingCHOLESTEROLslipid.txt', 'COUNT': [42, 44]}, 'POPC': {'NAME': 'POPC', 'MAPPING': 'mappingPOPCslipids.txt', 'COUNT': [100, 100]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingTIP3PwaterSlipids.txt', 'COUNT': 9000}, 'CAL': {'NAME': 'CA', 'MAPPING': 'mappingCA.txt', 'COUNT': 73}, 'CLA': {'NAME': 'CL', 'MAPPING': 'mappingCL.txt', 'COUNT': 146}}
# TRAJECTORY_SIZE : 4485323124
# TRJLENGTH : 2000100.0
# TEMPERATURE : 310.0
# NUMBER_OF_ATOMS : 60383
# DATEOFRUNNING : 01/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'CHOL': {}, 'POPC': {}}
# path : ../../Databank/Data/Simulations/8a4/d1e/8a4d1ef506194f34756b450fdb85cd25b2622685/42e758d0b36ac79a7cc9a8093dae1d79324d5f29/
#
# AUTHORS_CONTACT : Martinez-Seara, Hector
# FF_DATE : None
# SYSTEM : 72DPPC_2188SOL_325K_rmcomm_leaflets
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 325.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 15924
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : CHARMM-GUI v1.6
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [36, 36], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 2188, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DPPC_72_325K_rmcomm_leaflets_low_hydration_md.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 294825836
# SOFTWARE_VERSION : 5.0.4
# FF : CHARMM36 (center of mass removed independently for upper leaflet, lower leaflet and water+ions)
# TOP : [['DPPC_72_325K_rmcomm_leaflets_low_hydration_md.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1009607
# DATEOFRUNNING : 12/10/2021
# TPR : [['DPPC_72_325K_rmcomm_leaflets_low_hydration_md.tpr']]
# TRJ : [['DPPC_72_325K_rmcomm_leaflets_low_hydration_md.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/8b4/def/8b4defac09883665a8c2e32302d5080664fc77aa/f0b754bfeb545d99e3d319216c6894adbf27fee2/
#
# FF_DATE : 26/3/2020
# POPG : POPG
# SYSTEM : POPC:POPE(1:1)_T300K
# TYPEOFSYSTEM : lipid bilayer
# POPS : POPS
# NUMBER_OF_ATOMS : 31936
# EXPERIMENT : {'POPC': {}, 'POPE': {}}
# FF_SOURCE : 10.5281/zenodo.3725637
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [32, 32], 'MAPPING': 'mappingPOPCmacrogFUCHS.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 5120, 'MAPPING': 'mappingTIP3Pwater.txt'}, 'POPE': {'NAME': 'POPE', 'COUNT': [32, 32], 'MAPPING': 'mappingPOPEmacrogFUCHS.txt'}}
# TIMELEFTOUT : 200
# TRJLENGTH : 500100.0
# DATEOFRUNNING : 01/10/2021
# FF : MacRog
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3725637
# TRAJECTORY_SIZE : 583257372
# TPR : [['md.tpr']]
# TRJ : [['md_OK_100.xtc']]
# TEMPERATURE : 300.0
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/8bd/67c/8bd67cee9e378f25ad0826c4da436e44d72038be/6a3d11e69a7d3d3bac227a6ba9b74b05548c2fe6/
#
# AUTHORS_CONTACT : Fernando Favela
# TYPEOFSYSTEM : lipid bilayer
# SYSTEM : POPC:CHOL(1:1)_T298K
# TEMPERATURE : 298.0
# DATEOFRUNNING : 04/10/2021
# NUMBER_OF_ATOMS : 114250
# EXPERIMENT : {'CHOL': {'10.1039/c2cp42738a': '10.1039/c2cp42738a/5'}, 'POPC': {'10.1039/c2cp42738a': '10.1039/c2cp42738a/5'}}
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [128, 128], 'MAPPING': 'mappingCHOLESTEROLslipid.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [128, 128], 'MAPPING': 'mappingPOPCslipids.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 20334, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# TRJLENGTH : 100100.0
# SOFTWARE_VERSION : 4.6.3
# FF : slipids
# SOFTWARE : gromacs
# PREEQTIME : 70
# DOI : 10.5281/zenodo.159434
# TRAJECTORY_SIZE : 425433616
# TPR : [['popc50_T298_every100ps.tpr']]
# TRJ : [['popc50_T298_every100ps.xtc']]
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/8cb/989/8cb989e1813b93d1144d731ffbbc04a5cfcfb6a6/2db4e1d512355edd21cedbc0d28a45659dd6faa9/
#
# AUTHORS_CONTACT : Walter, Vivien; Ruscher, Celine; Benzerara, Olivier; Marques, Carlos; Thalmann, Fabrice
# FF_DATE : June 2015
# SYSTEM : 212DPPC_29826SOL_348K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 348.0
# PUBLICATION : 10.1039/D0CP02058C
# NUMBER_OF_ATOMS : 117038
# EXPERIMENT : {'DPPC': {}}
# FF_SOURCE : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [106, 106], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 29826, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 49240.0
# TRAJECTORY_SIZE : 4294967295
# SOFTWARE_VERSION : 2016.4
# FF : CHARMM36
# TOP : None
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3950029
# DATEOFRUNNING : 05/10/2021
# TPR : [['dppc_348k.tpr']]
# TRJ : [['dppc_348k.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/8ce/23b/8ce23bb33af41c05a6f9e78ee540b0f0b3d80b61/8e30fa47b8446f2eb523b55d501f6c6ea6e39675/
#
# DOI : 10.5281/zenodo.32173
# SOFTWARE : gromacs
# TRJ : [['popcCACL_50-108ns.xtc']]
# TPR : [['popcCACL.tpr']]
# PREEQTIME : 50
# TIMELEFTOUT : 0
# UNITEDATOM_DICT : {'POPC': 'Berger_PLA'}
# COMPOSITION : {'POPC': {'NAME': 'PLA', 'MAPPING': 'mappingPOPCberger.txt', 'COUNT': [64, 64]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingSPCwater.txt', 'COUNT': 7157}, 'CAL': {'NAME': 'CA', 'MAPPING': 'mappingCALecc.txt', 'COUNT': 44}, 'CLA': {'NAME': 'CL', 'MAPPING': 'mappingCLAecc.txt', 'COUNT': 88}}
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# PUBLICATION : Phys. Chem. Chem. Phys., 2016, 18, 32560--32569 (NMRlipids II)
# AUTHORS_CONTACT : Samuli Ollila (samuli.ollila@helsinki.fi)
# SYSTEM : POPC_310K_with_CaCl
# SOFTWARE_VERSION : 4.5
# FF : Berger
# FF_SOURCE : J. Phys. Chem. B 2007, 111, 3139-3150
# FF_DATE : None
# TOP : [['popcCACL.top']]
# TRAJECTORY_SIZE : 597638764
# TRJLENGTH : 58010.0
# TEMPERATURE : 298.0
# NUMBER_OF_ATOMS : 28259
# DATEOFRUNNING : 04/12/2021
# TYPEOFSYSTEM : lipid bilayer
# path : ../../Databank/Data/Simulations/8d8/5c6/8d85c662a53e14e285a3bcfb75c55f3fef35be4b/343a5f2b56bf580ab0e4fb5d444c2c947c825dd3/
#
# DOI : 10.5281/zenodo.1230390
# SOFTWARE : gromacs
# TRJ : [['01-CER160_50_POPC_512_NaCL_150mM_310K_md.xtc']]
# TPR : [['01-CER160_50_POPC_512_NaCL_150mM_310K_md.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : 10.1021/acscentsci.7b00582
# AUTHORS_CONTACT : Hector Martinez-Seara
# SYSTEM : 512POPC_50CER_28100SOL_75SOD_75CLA_310K
# SOFTWARE_VERSION : 2016.2
# FF : CHARMM36
# FF_SOURCE : CHARMM-GUI v1.7
# FF_DATE : None
# CPT : [['01-CER160_50_POPC_512_NaCL_150mM_310K_md.cpt']]
# LOG : [['01-CER160_50_POPC_512_NaCL_150mM_310K_md.log']]
# TOP : [['01-CER160_50_POPC_512_NaCL_150mM_310K_md.top']]
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'MAPPING': 'mappingPOPCcharmm.txt', 'COUNT': [256, 256]}, 'CER': {'NAME': 'CER160', 'MAPPING': 'mappingCERcharmm.txt', 'COUNT': [25, 25]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingSPCwater.txt', 'COUNT': 28100}, 'SOD': {'NAME': 'NA', 'MAPPING': 'mappingNA.txt', 'COUNT': 75}, 'CLA': {'NAME': 'CL', 'MAPPING': 'mappingCL.txt', 'COUNT': 75}}
# TRAJECTORY_SIZE : 20721879028
# TRJLENGTH : 3496800.0
# TEMPERATURE : 310.0
# NUMBER_OF_ATOMS : 158308
# DATEOFRUNNING : 11/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'POPC': {}, 'CER': {}}
# path : ../../Databank/Data/Simulations/8f4/59c/8f459c415f10c8871360ca97ce3d29b4ba956142/91b5cc9714f20ded49639d9dcbaeaf84566bf6d0/
#
# FF_DATE : ??
# TYPEOFSYSTEM : lipid bilayer
# SYSTEM : POPC_POPG_1:1_1000mMCaCL2
# TEMPERATURE : 298.0
# NUMBER_OF_ATOMS : 72626
# EXPERIMENT : {'POPG': {}, 'POPC': {}}
# FF_SOURCE : http://www.fos.su.se/~sasha/SLipids/,  https://bitbucket.org/hseara/ions/
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [64, 64], 'MAPPING': 'mappingPOPGslipids.txt'}, 'CLA': {'NAME': 'CL', 'COUNT': 460, 'MAPPING': 'mappingCLA.txt'}, 'CAL': {'NAME': 'CA', 'COUNT': 230, 'MAPPING': 'mappingCAL.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 128, 'MAPPING': 'mappingSOD.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [64, 64], 'MAPPING': 'mappingPOPCslipids.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 12800, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# TIMELEFTOUT : 500
# TRJLENGTH : 1000100.0
# DATEOFRUNNING : 01/10/2021
# FF : Slipids
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3613573
# TRAJECTORY_SIZE : 2715109772
# ...
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100010.0
# TRAJECTORY_SIZE : 5164944108
# SOFTWARE_VERSION : 5.1.2
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 400
# DOI : 10.5281/zenodo.2579108
# DATEOFRUNNING : 05/10/2021
# TPR : [['md_04.tpr']]
# TRJ : [['m_400_500_PG_PE_1_3_charmm.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/992/e7c/992e7cb56567854f229a3c45e0452a7bbb7a0ba7/d62a844544afff27fb2bc25fdcce9359a5717989/
#
# DOI : 10.5281/zenodo.3243329
# SOFTWARE : gromacs
# TRJ : [['chol50_500ns.xtc']]
# TPR : [['chol50.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Javanainen, Matti
# SYSTEM : 200POPC_9000SOL_200CHOL_310K
# SOFTWARE_VERSION : 4.6
# FF : Slipids
# FF_SOURCE : http://mmkluster.fos.su.se/slipids/
# FF_DATE : pre-2020
# CPT : [['chol50_500ns.cpt']]
# LOG : None
# TOP : [['chol50.top']]
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'MAPPING': 'mappingPOPCslipids.txt', 'COUNT': [100, 100]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingTIP3PwaterSlipids.txt', 'COUNT': 18000}, 'CHOL': {'NAME': 'CHL1', 'MAPPING': 'mappingCHOLESTEROLslipid.txt', 'COUNT': [100, 100]}}
# TRAJECTORY_SIZE : 1763736716
# TRJLENGTH : 500100.0
# TEMPERATURE : 310.0
# NUMBER_OF_ATOMS : 95600
# DATEOFRUNNING : 22/10/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'POPC': {}, 'CHOL': {}}
# path : ../../Databank/Data/Simulations/999/60d/99960db731abc24358eea3b5edf4eaff335c1ba3/cdf412c4bd1e99664ba8d0995e5490480942938c/
#
# DOI : 10.5281/zenodo.546136
# SOFTWARE : gromacs
# TRJ : [['md50ns_chunk02.xtc']]
# TPR : [['md50ns_chunk01.tpr']]
# PREEQTIME : 150
# TIMELEFTOUT : 0
# COMPOSITION : {'DPPG': {'NAME': 'DPPG', 'MAPPING': 'mappingDPPGslipids.txt', 'COUNT': [144, 144]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingSPCwater.txt', 'COUNT': 11232}, 'SOD': {'NAME': 'NA', 'MAPPING': 'mappingNA.txt', 'COUNT': 288}}
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# PUBLICATION : None
# AUTHORS_CONTACT : Favela-Rosales, Fernando
# SYSTEM : 288DPPG_11232SOL_288SOD_314K
# SOFTWARE_VERSION : 5.0.4
# FF : Slipids
# FF_SOURCE : None
# FF_DATE : pre-2020
# CPT : None
# LOG : None
# TOP : None
# TRAJECTORY_SIZE : 646232904
# TRJLENGTH : 50020.0
# TEMPERATURE : 314.0
# NUMBER_OF_ATOMS : 69408
# DATEOFRUNNING : 02/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'DPPG': {}}
# path : ../../Databank/Data/Simulations/9a8/b91/9a8b913b3ef4edd0590ee766bf95ef122b4cc8f5/189ac1c9fab4ddc8a1fd9a2d174e84dbd7d5323a/
#
# AUTHORS_CONTACT : Girych Mykhailo and Ollila O. H. Samuli
# FF_DATE : None
# SYSTEM : POPC_CHARMM36_CaCl2_035Mol_303K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 303.0
# NUMBER_OF_ATOMS : 36457
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'SOL': {'NAME': 'TIP3', 'COUNT': 6400, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [64, 64], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'CAL': {'NAME': 'CAL', 'COUNT': 35, 'MAPPING': 'mappingCAL.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 70, 'MAPPING': 'mappingCLA.txt'}}
# TIMELEFTOUT : 0
# TRJLENGTH : 100010.0
# DATEOFRUNNING : 01/10/2021
# EXPERIMENT : {'POPC': {}}
# SOFTWARE_VERSION : 5.0.4
# TOP : [['topol.top']]
# PREEQTIME : 100
# DOI : 10.5281/zenodo.35159
# TRAJECTORY_SIZE : 1351974812
# TPR : [['035M_CaCl2_POPC_CRM36.tpr']]
# TRJ : [['035M_CaCl2_POPC_CRM36_100_200ns.xtc']]
# LOG : [['md.log']]
# SOFTWARE : gromacs
# CPT : None
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/9b3/085/9b3085df71a90fb15bde7f9152d811fc1b1ad346/79a426c93cd61c106a63f07bd053a1ac0c526ddd/
#
# AUTHORS_CONTACT : Javanainen, Matti
# FF_DATE : None
# SYSTEM : 260DAPC_28CHOL_11520SOL_298K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 72512
# EXPERIMENT : {'CHOL': {}, 'DAPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'CHOL': {'NAME': 'CHL1', 'COUNT': [15, 13], 'MAPPING': 'mappingCHOLESTEROLcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 11520, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'DAPC': {'NAME': 'DAPC', 'COUNT': [130, 130], 'MAPPING': 'mappingDAPCcharmm.txt'}}
# TIMELEFTOUT : 0
# CPT : [['DAPC_AA_CHOL10_CORE_298.cpt']]
# TRJLENGTH : 2000100.0
# TRAJECTORY_SIZE : 5411814848
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['DAPC_AA_CHOL10_CORE.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.2653735
# DATEOFRUNNING : 06/10/2021
# TPR : [['DAPC_AA_CHOL10_CORE_298.tpr']]
# TRJ : [['DAPC_AA_CHOL10_CORE_298.xtc']]
# LOG : [['DAPC_AA_CHOL10_CORE_298.log']]
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/9d2/67f/9d267f56ef99de1cb49df40a6da0c1da899b1ec8/fccd67de4e74b6b5fe026898b32d34bbeca2fb81/
#
# DOI : 10.5281/zenodo.4522359
# SOFTWARE : gromacs
# TRJ : [['dppc_256_CharmmGUI.xtc']]
# TPR : [['dppc_256_CharmmGUI.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'COUNT': [128, 128], 'MAPPING': 'mappingDPPCcharmm.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 42642, 'MAPPING': 'mappingTIP3Pwater.txt'}}
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : 10.1016/j.bbamem.2021.183714
# AUTHORS_CONTACT : Walter, Vivien; Ruscher, Celine; Gola, Adrien; Marques, Carlos; Benzerara, Olivier; Thalmann, Fabrice
# SYSTEM : 256DPPC_42642SOL_288K
# SOFTWARE_VERSION : 2016.4
# FF : CHARMM36
# FF_SOURCE : None
# FF_DATE : June 2015
# CPT : None
# LOG : None
# TOP : None
# TRAJECTORY_SIZE : 5967921544
# TRJLENGTH : 50005.0
# TEMPERATURE : 288.0
# NUMBER_OF_ATOMS : 161206
# DATEOFRUNNING : 23/10/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'DPPC': {}}
# path : ../../Databank/Data/Simulations/a00/2c2/a002c28997069825fa42a6b751369d8062533e14/757216c36b032096aca0f434eba8799fcd5e3860/
#
# AUTHORS_CONTACT : Matti Javanainen
# FF_DATE : None
# SYSTEM : 200DLPC_10000SOL_23SOD_23CLA
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 310.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 51246
# EXPERIMENT : {'DLPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'DLPC': {'NAME': 'DLPC', 'COUNT': [100, 100], 'MAPPING': 'mappingDLPCcharmm.txt'}, 'SOD': {'NAME': 'SOD', 'COUNT': 23, 'MAPPING': 'mappingSOD.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 10000, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 23, 'MAPPING': 'mappingCLA.txt'}}
# TIMELEFTOUT : 0
# CPT : [['dlpc.cpt']]
# TRJLENGTH : 500100.0
# TRAJECTORY_SIZE : 934589544
# SOFTWARE_VERSION : 2019
# FF : CHARMM36
# TOP : [['dlpc.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3592499
# DATEOFRUNNING : 01/10/2021
# TPR : [['dlpc.tpr']]
# TRJ : [['dlpc.xtc']]
# LOG : [['dlpc.log']]
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/a48/859/a4885929c7f32ab1e404e4996c0a8c8194d7f9d6/96b44569491b7798a614371ba18bad1064dd7732/
#
# AUTHORS_CONTACT : Ollila, O. H. S.
# FF_DATE : None
# SYSTEM : 110POPC_22POPS_4932SOL_101SOD_79CLA_298K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 32510
# EXPERIMENT : {'POPS': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPS': {'NAME': 'POPS', 'COUNT': [11, 11], 'MAPPING': 'mappingPOPScharmm.txt'}, 'CLA': {'NAME': 'CLA', 'COUNT': 79, 'MAPPING': 'mappingCLA.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [55, 55], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 4932, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}, 'SOD': {'NAME': 'SOD', 'COUNT': 101, 'MAPPING': 'mappingSOD.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 150010.0
# TRAJECTORY_SIZE : 1814930132
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 50
# DOI : 10.5281/zenodo.1493229
# DATEOFRUNNING : 01/10/2021
# TPR : [['topol.tpr']]
# TRJ : [['traj.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/a50/c1a/a50c1a131bc220af7d5cc8d1ebb212f98b866101/f54cd09a11c7d3c5a2e470823a4d1b83c54c1c55/
#
# FF_DATE : ??
# POPG : POPG
# SYSTEM : POPC_T300K
# TYPEOFSYSTEM : lipid bilayer
# POPS : POPS
# FFSOL : TIP3P
# NUMBER_OF_ATOMS : 63605
# EXPERIMENT : {'POPC': {'10.1039/c2cp42738a': '10.1039/c2cp42738a/1'}}
# FF_SOURCE : ??
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [128, 128], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 9767, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TRJ : [['md_dt100_OK_centered.xtc']]
# TIMELEFTOUT : 50
# POPE : POPE
# CLA : CL
# DATEOFRUNNING : 01/10/2021
# FF : CHARMM36
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.1306800
# TRAJECTORY_SIZE : 702797300
# TPR : [['md.tpr']]
# POT : K
# TEMPERATURE : 300.0
# CAL : CA
# SOD : NA
# TRJLENGTH : 300100.0
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/a63/ca7/a63ca7001cbd5cfc328da122668d1aebc00f2c91/220540156a6ac7813942fd01d998a491b6ff9b8b/
#
# AUTHORS_CONTACT : Thomas Piggot
# FF_DATE : pre-2020
# SYSTEM : 128DOPS_4880SOL_128SOD_303K_v1
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 303.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 30336
# EXPERIMENT : {'DOPS': {}}
# FF_SOURCE : starting structure from CHARMM-GUI
# COMPOSITION : {'DOPS': {'NAME': 'DOPS', 'COUNT': [64, 64], 'MAPPING': 'mappingDOPSslipids.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 4480, 'MAPPING': 'mappingSPCwater.txt'}, 'SOD': {'NAME': 'NA', 'COUNT': 128, 'MAPPING': 'mappingNA.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 100050.0
# TRAJECTORY_SIZE : 226007336
# SOFTWARE_VERSION : None
# FF : Slipids
# TOP : None
# PREEQTIME : 400
# DOI : 10.5281/zenodo.1129439
# DATEOFRUNNING : 12/10/2021
# TPR : [['for-md-Slipids_10A_cut-off_LJ-PME_DOPS_303K_v1.tpr']]
# TRJ : [['md-Slipids_LJ-PME_DOPS_v1_400-500ns_skip10.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /usr/home/bort/Databank
# path : ../../Databank/Data/Simulations/a71/d54/a71d54feeb142784debeffbade25b7b6e037a80a/4787a89478d4806c2111a211f4af8bb0715e927d/
#
# DOI : 10.5281/zenodo.495510
# SOFTWARE : gromacs
# TRJ : [['md50ns_chunk02.xtc']]
# TPR : [['md50ns_chunk01.tpr']]
# PREEQTIME : 150
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Favela-Rosales, Fernando
# SYSTEM : 288DOPS_11232SOL_288SOD_303K
# SOFTWARE_VERSION : 5.0.4
# FF : Slipids
# FF_SOURCE : None
# FF_DATE : pre-2020
# CPT : None
# LOG : None
# TOP : None
# COMPOSITION : {'DOPS': {'NAME': 'DOPS', 'MAPPING': 'mappingDOPSslipids.txt', 'COUNT': [144, 144]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingSPCwater.txt', 'COUNT': 11232}, 'SOD': {'NAME': 'NA', 'MAPPING': 'mappingNA.txt', 'COUNT': 288}}
# TRAJECTORY_SIZE : 668567244
# TRJLENGTH : 50020.0
# TEMPERATURE : 303.0
# NUMBER_OF_ATOMS : 71712
# DATEOFRUNNING : 01/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'DOPS': {}}
# path : ../../Databank/Data/Simulations/aa8/3d4/aa83d427cf495177dfceb987c21d57388f98b79f/b32c12316d8452925a2e9009c0e3c48732fd40ef/
#
# AUTHORS_CONTACT : Nencini, Ricky
# FF_DATE : None
# SYSTEM : 250POPC_50POPS_11174SOL_50SOD_189CAL_378CLA_320K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 320.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 73989
# EXPERIMENT : {'POPS': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'CLA': {'NAME': 'CLA', 'COUNT': 378, 'MAPPING': 'mappingCLA.txt'}, 'CAL': {'NAME': 'CAL', 'COUNT': 189, 'MAPPING': 'mappingCAL.txt'}, 'SOD': {'NAME': 'SOD', 'COUNT': 50, 'MAPPING': 'mappingSOD.txt'}, 'POPS': {'NAME': 'POPS', 'COUNT': [25, 25], 'MAPPING': 'mappingPOPScharmm.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [125, 125], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 11174, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 137
# CPT : [['popc_pops_250_50_contra_sodium_940mM_CaCl_nbfix_han.cpt']]
# TRJLENGTH : 436600.0
# TRAJECTORY_SIZE : 1208113740
# SOFTWARE_VERSION : 2018.6
# FF : CHARMM36 with NBFIX for calcium ions
# TOP : [['popc_pops_250_50_contra_sodium_940mM_CaCl_nbfix_han.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3371327
# DATEOFRUNNING : 01/10/2021
# TPR : [['popc_pops_250_50_contra_sodium_940mM_CaCl_nbfix_han.tpr']]
# TRJ : [['popc_pops_250_50_contra_sodium_940mM_CaCl_nbfix_han.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/ac0/992/ac0992c74e87361fbbfcc9e64507b5de2ffd6b12/2bae4180a38766f03b70977d1a998b5cfe290f4a/
#
# DOI : 10.5281/zenodo.3539129
# SOFTWARE : gromacs
# TRJ : [['dppc_300.xtc']]
# TPR : [['dppc_300.tpr']]
# PREEQTIME : 0
# TIMELEFTOUT : 0
# DIR_WRK : /usr/home/bort/Databank
# PUBLICATION : None
# AUTHORS_CONTACT : Javanainen, Matti; Martinez-Seara, Hector; Vattulainen, Ilpo
# SYSTEM : 1152DPPC_46440SOL_124SOD_124CLA_300K
# SOFTWARE_VERSION : None
# FF : Slipids
# FF_SOURCE : None
# FF_DATE : pre-2020
# CPT : [['dppc_300.cpt']]
# LOG : [['dppc_300.log']]
# TOP : None
# COMPOSITION : {'DPPC': {'NAME': 'DPPC', 'MAPPING': 'mappingDPPCslipid.txt', 'COUNT': [576, 576]}, 'SOL': {'NAME': 'SOL', 'MAPPING': 'mappingTIP3PwaterSlipids.txt', 'COUNT': 46440}, 'SOD': {'NAME': 'NA', 'MAPPING': 'mappingNA.txt', 'COUNT': 124}, 'CLA': {'NAME': 'CL', 'MAPPING': 'mappingCL.txt', 'COUNT': 124}}
# TRAJECTORY_SIZE : 5403749940
# TRJLENGTH : 500100.0
# TEMPERATURE : 300.0
# NUMBER_OF_ATOMS : 289328
# DATEOFRUNNING : 01/11/2021
# TYPEOFSYSTEM : lipid bilayer
# EXPERIMENT : {'DPPC': {}}
# path : ../../Databank/Data/Simulations/ac2/651/ac265157c0b640f701dacff0f46c2eb25392b4a3/386a224988e3b7a2fe053b893ebc601111027dd4/
#
# AUTHORS_CONTACT : Samuli Ollila (samuli.ollila@helsinki.fi)
# FF_DATE : ?/?/????
# SYSTEM : POPC_T298K
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# UNITEDATOM_DICT : {'POPC': 'Berger_PLA'}
# PUBLICATION : Ferreira et al. Phys. Chem. Chem. Phys., 2013,15, 1976-1989
# FFSOL : SPC
# NUMBER_OF_ATOMS : 28526
# EXPERIMENT : {'POPC': {'10.1039/c2cp42738a': '10.1039/c2cp42738a/1'}}
# FF_SOURCE : http://wcm.ucalgary.ca/tieleman/downloads
# COMPOSITION : {'POPC': {'NAME': 'PLA', 'COUNT': [64, 64], 'MAPPING': 'mappingPOPCberger.txt'}, 'SOL': {'NAME': 'SOL', 'COUNT': 7290, 'MAPPING': 'mappingSPCwater.txt'}}
# TIMELEFTOUT : 0
# TRJLENGTH : 50010.0
# TRAJECTORY_SIZE : 3424404744
# SOFTWARE_VERSION : 4.5
# FF : Berger
# SOFTWARE : gromacs
# PREEQTIME : 270
# DOI : 10.5281/zenodo.4643875
# DATEOFRUNNING : 01/10/2021
# TPR : [['popc407.tpr']]
# TRJ : [['traj.trr']]
# TOP : [['topol.top']]
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/b06/79c/b0679cd5bb4bed509b91a002305d2771ed4ad54e/72ec31258e95aefa0d053131b9e734b4b11eb030/
#
# AUTHORS_CONTACT : Jesper J. Madsen
# FF_DATE : None
# SYSTEM : 400POPC_100POPG_100POT_298K_122392Atoms
# TYPEOFSYSTEM : lipid bilayer
# TEMPERATURE : 298.0
# PUBLICATION : None
# NUMBER_OF_ATOMS : 122392
# EXPERIMENT : {'POPG': {}, 'POPC': {}}
# FF_SOURCE : CHARMM-GUI v1.7
# COMPOSITION : {'POPG': {'NAME': 'POPG', 'COUNT': [50, 50], 'MAPPING': 'mappingPOPGcharmm.txt'}, 'POT': {'NAME': 'POT', 'COUNT': 100, 'MAPPING': 'mappingPOT.txt'}, 'POPC': {'NAME': 'POPC', 'COUNT': [200, 200], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 18664, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TIMELEFTOUT : 0
# CPT : None
# TRJLENGTH : 200100.0
# TRAJECTORY_SIZE : 919022796
# SOFTWARE_VERSION : None
# FF : CHARMM36
# TOP : [['topol.top']]
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3483783
# DATEOFRUNNING : 01/10/2021
# TPR : [['step7_1.tpr']]
# TRJ : [['run.wrapped.xtc']]
# LOG : None
# SOFTWARE : gromacs
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/b32/5fe/b325fe9c3294adbf74b4dbee14d31a90cb0d1127/aa71f45d8b1415cfa3e21bf46752f4a3b1832633/
#
# FF_DATE : ??
# POPG : POPG
# SYSTEM : POPC_T303K
# TYPEOFSYSTEM : lipid bilayer
# POPS : POPS
# FFSOL : TIP3P
# NUMBER_OF_ATOMS : 32512
# EXPERIMENT : {'POPC': {}}
# FF_SOURCE : ??
# COMPOSITION : {'POPC': {'NAME': 'POPC', 'COUNT': [64, 64], 'MAPPING': 'mappingPOPCcharmm.txt'}, 'SOL': {'NAME': 'TIP3', 'COUNT': 5120, 'MAPPING': 'mappingTIP3PCHARMMgui.txt'}}
# TRJ : [['traj_comp.xtc']]
# TIMELEFTOUT : 20
# POPE : POPE
# CLA : CL
# DATEOFRUNNING : 01/10/2021
# FF : CHARMM36
# SOFTWARE : gromacs
# PREEQTIME : 0
# DOI : 10.5281/zenodo.3474863
# TRAJECTORY_SIZE : 6035770840
# TPR : [['mdrun.tpr']]
# POT : K
# TEMPERATURE : 303.0
# CAL : CA
# SOD : NA
# TRJLENGTH : 500010.0
# DIR_WRK : /media/osollila/Data/tmp/DATABANK/
# path : ../../Databank/Data/Simulations/b4f/866/b4f866c0dabffa6cd891e91841591d46590f34aa/a231c358dd8c0b7bb4cf558ccdbf022373354a9a/

# %%
for system in systems:
    for molecule in system['COMPOSITION']:
        print(molecule)
    print(system['TEMPERATURE'])
    print('')
# Out:
# CHOL
# POPC
# SOL
# 310.15
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# POPC
# SOL
# 313.0
#
# POPS
# SOL
# SOD
# 298.0
#
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# CHOL
# SOL
# DAPC
# 310.0
#
# POPG
# SOL
# POPC
# CAL
# CLA
# 298.0
#
# CHOL
# SOL
# DOPC
# 310.0
#
# DPPC
# SOL
# 298.0
#
# DPPC
# SOL
# 288.0
#
# POPG
# POPC
# SOL
# SOD
# 298.0
#
# POPG
# SOL
# SOD
# 298.0
#
# CHOL
# POPC
# SOL
# 310.15
#
# POPC
# SOL
# 303.0
#
# POPS
# POT
# POPC
# SOL
# CLA
# 298.0
#
# DPPC
# SOL
# 325.0
#
# CHOL
# POPC
# SOL
# 310.15
#
# CHOL
# POPC
# SOL
# 303.0
#
# POPG
# SOL
# POPC
# CAL
# CLA
# 298.0
#
# DPPC
# SOL
# 325.0
#
# POPS
# POT
# POPC
# SOL
# 298.0
#
# DPPC
# SOL
# 358.0
#
# CHOL
# DPPC
# SOL
# 310.0
#
# POPC
# SOL
# 310.15
#
# POPG
# SOL
# SOD
# 310.0
#
# POPC
# SOL
# 303.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# CLA
# POPC
# SOL
# SOD
# 303.0
#
# CLA
# POPC
# SOL
# SOD
# 303.0
#
# POPC
# SOL
# CHOL
# 310.0
#
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# POPS
# POT
# POPC
# SOL
# 298.0
#
# CHOL
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# DPPC
# SOL
# SOD
# CLA
# 310.0
#
# POPC
# SOL
# 310.0
#
# CHOL
# POPC
# SOL
# SOD
# CLA
# 310.0
#
# DPPC
# SOL
# 288.0
#
# CHOL
# SOL
# DDOPC
# DOPC
# 310.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# CHOL
# POPC
# SOL
# CAL
# CLA
# 310.0
#
# DPPC
# SOL
# 325.0
#
# POPC
# SOL
# POPE
# 300.0
#
# CHOL
# POPC
# SOL
# 298.0
#
# DPPC
# SOL
# 348.0
#
# POPC
# SOL
# CAL
# CLA
# 298.0
#
# POPC
# CER
# SOL
# SOD
# CLA
# 310.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# DPPC
# SOL
# 328.0
#
# POPG
# SOL
# SOD
# 298.0
#
# POPS
# POT
# SOL
# 298.0
#
# SOL
# POPE
# 310.0
#
# CLA
# POPC
# SOL
# DHMDMAB
# 313.0
#
# CHOL
# SOL
# DAPC
# 310.0
#
# POPC
# SOL
# 303.0
#
# POPC
# SOL
# 303.0
#
# POPG
# POPC
# SOL
# SOD
# 298.0
#
# POPC
# SOL
# 303.0
#
# CLA
# POPC
# SOL
# SOD
# 310.15
#
# POPC
# CER
# SOL
# SOD
# CLA
# 310.0
#
# POPG
# POPC
# SOL
# SOD
# 310.0
#
# POPC
# SOL
# 310.0
#
# DEPC
# SOD
# SOL
# CLA
# 310.0
#
# POPC
# SOL
# CHOL
# 310.0
#
# POPG
# POPC
# SOL
# SOD
# 298.0
#
# CHOL
# SOL
# DAPC
# 310.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# DPPG
# SOL
# SOD
# 298.0
#
# CHOL
# SOL
# DAPC
# 320.0
#
# POPC
# SOL
# 310.0
#
# DPPC
# SOD
# SOL
# CLA
# 338.0
#
# POPC
# SOL
# 310.15
#
# POPS
# SOL
# SOD
# 298.0
#
# POPC
# SOL
# 303.15
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# CHOL
# POPC
# SOL
# 303.15
#
# CHOL
# POPC
# SOL
# 310.0
#
# DPPE
# SOL
# 336.0
#
# DPPC
# SOL
# 288.0
#
# POPC
# SOL
# 310.15
#
# CHOL
# POPC
# SOL
# 310.0
#
# POPS
# POT
# SOL
# 298.0
#
# CHOL
# SOL
# DAPC
# 333.0
#
# POPC
# SOL
# 310.0
#
# CLA
# POPC
# SOL
# SOD
# 303.0
#
# POPC
# SOL
# POPE
# 300.0
#
# POPC
# SOL
# 303.0
#
# POPC
# CER
# SOL
# SOD
# CLA
# 310.0
#
# POPC
# SOL
# 303.0
#
# CHOL
# POPC
# SOL
# SOD
# CLA
# 310.0
#
# CHOL
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# CLA
# SOL
# DOPC
# SOD
# 310.0
#
# CHOL
# CLA
# POPC
# SOL
# SOD
# 310.15
#
# POPC
# SOL
# 303.0
#
# CHOL
# POPC
# SOL
# 303.0
#
# POPC
# CER
# SOL
# SOD
# CLA
# 310.0
#
# DPPC
# SOD
# SOL
# CLA
# 322.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPG
# SOL
# POPE
# SOD
# 310.0
#
# DPPC
# SOL
# 323.0
#
# SOL
# POPC
# CAL
# CLA
# 310.0
#
# POPC
# SOL
# CAL
# CLA
# 310.0
#
# CHOL
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# DPPC
# SOL
# 358.0
#
# POPC
# SOL
# 310.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# POPS
# CLA
# POPC
# SOL
# SOD
# 298.0
#
# POPC
# SOL
# 303.0
#
# POPC
# SOL
# CHOL
# 310.0
#
# POPC
# SOL
# 298.0
#
# DPPC
# SOL
# 308.0
#
# POPC
# SOL
# SOD
# CLA
# 310.0
#
# POPC
# SOL
# 303.0
#
# DPPC
# SOL
# SOD
# CLA
# 305.0
#
# POPC
# SOL
# 303.0
#
# DMPC
# CLA
# SAPI
# SOD
# POPI
# SOL
# SLPI
# 303.15
#
# POPS
# POPC
# SOL
# SOD
# 298.0
#
# POPS
# POPC
# SOL
# SOD
# 320.0
#
# CHOL
# CLA
# POPC
# SOL
# SOD
# 310.15
#
# CHOL
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# DPPC
# SOD
# SOL
# CLA
# 320.0
#
# DPPC
# SOD
# SOL
# CLA
# 320.0
#
# POPG
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# DPPC
# SOD
# SOL
# CLA
# 320.0
#
# DPPC
# SOD
# SOL
# CLA
# 320.0
#
# CLA
# POPC
# SOL
# DHMDMAB
# 313.0
#
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# CHOL
# SOL
# DLIPC
# 310.0
#
# CLA
# SOL
# POPE
# SOD
# 310.0
#
# POPC
# SOL
# 303.0
#
# POPG
# POT
# POPC
# SOL
# 298.0
#
# CHOL
# POPC
# SOL
# 303.0
#
# POPG
# SOL
# POPE
# SOD
# 310.0
#
# CHOL
# SOL
# DLIPC
# DOPC
# 310.0
#
# CLA
# POPC
# SOL
# DHMDMAB
# 313.0
#
# POPS
# POT
# POPC
# SOL
# 298.0
#
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# POPC
# SOL
# 310.15
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# CHOL
# SOL
# DAPC
# 310.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPC
# SOL
# POPE
# 298.0
#
# POPC
# SOL
# 303.0
#
# CHOL
# POPC
# SOL
# CAL
# CLA
# 310.0
#
# DPPC
# SOL
# 338.0
#
# POPC
# SOL
# 303.0
#
# POPC
# SOL
# 303.0
#
# POPC
# SOL
# 303.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# CLA
# POPC
# SOL
# SOD
# 310.15
#
# CHOL
# SOL
# DDOPC
# 310.0
#
# POPS
# SOL
# POPC
# CAL
# CLA
# 298.0
#
# DPPC
# SOL
# 325.0
#
# SOL
# POPC
# CAL
# CLA
# 303.0
#
# POPG
# POPC
# SOL
# SOD
# 298.0
#
# CHOL
# POPC
# SOL
# 303.15
#
# POPC
# SOL
# 310.15
#
# POPG
# SOL
# SOD
# 310.0
#
# POPC
# SOL
# 303.0
#
# DPPC
# SOL
# 318.0
#
# CHOL
# POPC
# SOL
# CAL
# CLA
# 310.0
#
# POPS
# POPC
# SOL
# SOD
# 298.0
#
# POPS
# POT
# POPC
# SOL
# CLA
# 298.0
#
# CHOL
# POPC
# SOL
# 303.15
#
# POPG
# POPC
# SOL
# SOD
# 310.0
#
# CHOL
# SOL
# DAPC
# 285.0
#
# CLA
# DSPC
# SOL
# SOD
# 338.0
#
# POPS
# SOL
# POPC
# CAL
# CLA
# 298.0
#
# POPC
# SOL
# 310.0
#
# POPS
# POT
# POPC
# SOL
# 298.0
#
# SOL
# POPC
# CAL
# CLA
# 303.0
#
# CHOL
# SOL
# DAPC
# 310.0
#
# POPG
# CLA
# SOL
# SOD
# 310.0
#
# CLA
# POPC
# SOL
# DHMDMAB
# 313.0
#
# POPC
# SOL
# 303.0
#
# CLA
# POPC
# SOL
# SOD
# 310.15
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPC
# SOL
# SOD
# CLA
# 310.0
#
# CHOL
# POPC
# SOL
# 303.15
#
# DPPC
# SOD
# SOL
# CLA
# 315.0
#
# POPS
# SOL
# SOD
# 298.0
#
# POPC
# SOL
# 303.0
#
# SOL
# POPC
# CAL
# CLA
# 310.0
#
# CHOL
# SOL
# DAPC
# 298.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# CHOL
# SOL
# DAPC
# 333.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# CHOL
# SOL
# DAPC
# 310.0
#
# POPG
# CLA
# SOL
# POPE
# SOD
# 310.0
#
# DOPS
# SOL
# SOD
# 303.0
#
# CLA
# POPC
# SOL
# SOD
# 310.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPS
# SOL
# SOD
# 298.0
#
# DPPC
# SOD
# SOL
# CLA
# 338.0
#
# SOL
# POPC
# CAL
# CLA
# 303.0
#
# CHOL
# POPC
# SOL
# 303.0
#
# DPPC
# SOD
# SOL
# CLA
# 325.0
#
# CHOL
# SOL
# DAPC
# 320.0
#
# POPC
# SOL
# 310.15
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# POPC
# SOL
# 303.0
#
# CHOL
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# POPC
# SOL
# 310.0
#
# CLA
# CAL
# SOD
# POPS
# POPC
# SOL
# 320.0
#
# POPG
# SOL
# POPC
# CAL
# CLA
# 298.0
#
# POPC
# SOL
# 303.0
#
# POPG
# POPC
# SOL
# SOD
# 298.0
#
# POPC
# SOL
# CHOL
# 310.0
#
# CHOL
# POPC
# SOL
# SOD
# CLA
# 310.0
#
# CHOL
# SOL
# DAPC
# 285.0
#
# POPC
# SOL
# SOD
# 310.0
#
# DPPC
# SOD
# SOL
# CLA
# 325.0
#
# POPG
# POPC
# SOL
# SOD
# 298.0
#
# SOL
# POPE
# 310.0
#
# POPC
# SOL
# 310.0
#
# DPPC
# SOD
# SOL
# CLA
# 325.0
#
# CHOL
# CLA
# POPC
# SOL
# SOD
# 310.15
#
# DOPS
# SOL
# SOD
# 303.0
#
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# POPC
# CER
# SOL
# SOD
# CLA
# 310.0
#
# CLA
# DSPC
# SOL
# SOD
# 333.0
#
# CHOL
# POPC
# SOL
# 298.0
#
# POPG
# CLA
# CAL
# SOD
# POPC
# SOL
# 298.0
#
# DPPC
# SOL
# 323.0
#
# DOPS
# SOL
# SOD
# 303.0
#
# POPG
# SOL
# SOD
# 310.0
#
# CHOL
# SOL
# DOPC
# DAPC
# 310.0
#
# CHOL
# SOL
# POPC
# CAL
# CLA
# 310.15
#
# POPG
# CLA
# SOL
# POPE
# SOD
# 310.0
#
# POPC
# SOL
# CHOL
# 310.0
#
# DPPG
# SOL
# SOD
# 314.0
#
# SOL
# POPC
# CAL
# CLA
# 303.0
#
# CHOL
# SOL
# DAPC
# 298.0
#
# DPPC
# SOL
# 288.0
#
# DLPC
# SOD
# SOL
# CLA
# 310.0
#
# POPS
# CLA
# POPC
# SOL
# SOD
# 298.0
#
# POPC
# SOL
# 300.0
#
# DOPS
# SOL
# SOD
# 303.0
#
# DOPS
# SOL
# SOD
# 303.0
#
# CLA
# CAL
# SOD
# POPS
# POPC
# SOL
# 320.0
#
# DPPC
# SOL
# SOD
# CLA
# 300.0
#
# POPC
# SOL
# 298.0
#
# POPG
# POT
# POPC
# SOL
# 298.0
#
# POPC
# SOL
# 303.0
